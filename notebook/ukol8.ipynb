# %%
import pandas as pd
adopce = pd.read_csv("adopce.csv", sep =";")
adopce.info()
adopce.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           513 non-null    float64
#  1   nazev_cz     513 non-null    object
#  2   nazev_en     513 non-null    object
#  3   trida_cz     513 non-null    object
#  4   cena         513 non-null    float64
#  5   k_prohlidce  513 non-null    float64
#  6   Unnamed: 6   0 non-null      float64
# dtypes: float64(4), object(3)
# memory usage: 28.2+ KB
# Index(['id', 'nazev_cz', 'nazev_en', 'trida_cz', 'cena', 'k_prohlidce',
#        'Unnamed: 6'],
#       dtype='object')

# %%
len(adopce)
# Out:
# 514

# %%
adopce.iloc[34][1:3]
# Out:
# nazev_cz     Ibis bílý
# nazev_en    White ibis
# Name: 34, dtype: object

# %%
adopce = pd.read_csv("adopce.csv", sep =";", index_col=1)
adopce
# Out:
#                          id                     nazev_en       trida_cz  \
# nazev_cz
# Šváb syčivý             7.0  Madagascar giant cockroach      Bezobratlí
# Pakobylka okřídlená     8.0     Pink-winged stick insect     Bezobratlí
# Tayra                  16.0                        Tayra          Savci
# Kajmanka supí          35.0    Alligator snapping turtle          Plazi
# Želva žlutočelá        37.0       Indochinese box turtle          Plazi
# ...                     ...                          ...            ...
# Létavka obecná       1418.0                               Obojživelníci
# Bažant paví          1419.0                                       Ptáci
# Sojkovec rezavouchý  1420.0                                       Ptáci
# Kachnice kaštanová   1421.0                                       Ptáci
# NaN                     NaN                          NaN            NaN
#
#                        cena  k_prohlidce  Unnamed: 6
# nazev_cz
# ...

# %%
adopce.index.is_unique
# Out:
# True

# %%
adopce_new = adopce.sort_index()
adopce_new.loc["Outloň váhavý"]
adopce_new.loc["Želva Smithova":"Želva žlutočelá"]
# Out:
#                                      id                        nazev_en  \
# nazev_cz
# Želva Smithova                   1117.0               Brown roof turtle
# Želva amboinská                   479.0              Malayan box turtle
# Želva annámská                    478.0          Vietnamese pond turtle
# Želva bahenní                    1115.0            European pond turtle
# Želva dlaždicovitá               1338.0              Impressed tortoise
# Želva egyptská                    980.0               Egyptian tortoise
# Želva hvězdnatá                  1412.0
# Želva korunkatá                  1112.0            Crowned river turtle
# Želva kubánská                    830.0          North Antillean slider
# Želva obrovská                     40.0          Aldabra giant tortoise
# Želva ostnitá                    1255.0                    Spiny turtle
# Želva pardálí                     763.0                Leopard tortoise
# ...
